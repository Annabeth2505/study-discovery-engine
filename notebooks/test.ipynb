# %%
import pandas as pd
import requests 
import yaml
import streamlit
import plotly
from Bio import Entrez 

print('all imports successful')
# Out:
# all imports successful

# %%
print('omg fun cool project yay')
# Out:
# omg fun cool project yay

# %%
print("pandas:", pd.__version__)
print("requests:", requests.__version__)
print("plotly:", plotly.__version__)
print("streamlit:", streamlit.__version__)
# Out:
# pandas: 2.3.3
# requests: 2.33.0
# plotly: 6.6.0
# streamlit: 1.55.0

# %%
data = {
    "study_id": ["PRJNA001", "PRJNA002", "PRJNA003"],
    "host": ["human", "mouse", "chicken"],
    "sequencing_type": ["16S", "WGS", "16S"],
    "sample_count": [150, 45, 200]
}

df = pd.DataFrame(data)
df
# Out:
#    study_id     host sequencing_type  sample_count
# 0  PRJNA001    human             16S           150
# 1  PRJNA002    mouse             WGS            45
# 2  PRJNA003  chicken             16S           200

# %%
Entrez.email = "akharya@ucsd.edu"

# %%
handle = Entrez.esearch(db= "sra", term = "gut microbiome 16s", retmax = 5)
record = Entrez.read(handle)
handle.close()

# %%
print('Number of results found:', record['Count'])
print ('First 5 IDs:', record['IdList'])
# Out:
# Number of results found: 561412
# First 5 IDs: ['43639516', '43639515', '43639514', '43639513', '43639512']

# %%
test_criteria = {
    "hard_filters" : {
    "has_16S": True, 
    "has_WGS": True, 
    "is_paired": True, 
    "has_fastq": True
    },
    "soft_scores": {
        "phylogenetic_gap": 0.4, 
        "metadata_completeness": 0.3,
        "geographic_gap": 0.2, 
        'sample_size': 0.1
    }
}

print(yaml.dump(test_criteria, default_flow_style = False))
# Out:
# hard_filters:
#   has_16S: true
#   has_WGS: true
#   has_fastq: true
#   is_paired: true
# soft_scores:
#   geographic_gap: 0.2
#   metadata_completeness: 0.3
#   phylogenetic_gap: 0.4
#   sample_size: 0.1

# %%
import sys
import os

sys.path.insert(0, os.path.abspath(".."))

# %%
import importlib 
import src.fetcher
importlib.reload(src.fetcher)

from src.fetcher import configure_entrez, fetch_sra_studies, fetch_runs_for_bioproject

configure_entrez()
# Out:
# Entrez configured with email: akharya@ucsd.edu

# %%
ids = fetch_sra_studies('amphibian gut microbiome 16s', max_results = 10)
print(ids)
# Out:
# Found 577 studies. Fetching 10...
#  Fetched 10 of 10
# ['40965287', '40965286', '40965285', '40965284', '40965283', '40965282', '40965281', '40965280', '40965279', '40965278']

# %%
single_id = ids[0]

runs_df = fetch_runs_for_bioproject([single_id])
print('shape:', runs_df.shape)
print('\nLibrary strategies found:')
print(runs_df['LibraryStrategy'].value_counts())
# Out:
# shape: (1, 47)
#
# Library strategies found:
# LibraryStrategy
# AMPLICON    1
# Name: count, dtype: int64

# %%
# debug - test the fetch manually
from Bio import Entrez
import pandas as pd
import io

single_id = ids[0]
print("Fetching ID:", single_id)

fetch_handle = Entrez.efetch(
    db="sra",
    id=single_id,
    rettype="runinfo",
    retmode="text"
)
data = fetch_handle.read()
fetch_handle.close()

print("Raw data type:", type(data))
print("First 500 chars:", data[:500])
# Out:
# Fetching ID: 40965287
# Raw data type: <class 'bytes'>
# First 500 chars: b'Run,ReleaseDate,LoadDate,spots,bases,spots_with_mates,avgLength,size_MB,AssemblyName,download_path,Experiment,LibraryName,LibraryStrategy,LibrarySelection,LibrarySource,LibraryLayout,InsertSize,InsertDev,Platform,Model,SRAStudy,BioProject,Study_Pubmed_id,ProjectID,Sample,BioSample,SampleType,TaxID,ScientificName,SampleName,g1k_pop_code,source,g1k_analysis_group,Subject_ID,Sex,Disease,Tumor,Affection_Status,Analyte_Type,Histological_Type,Body_Site,CenterName,Submission,dbgap_study_accession,Conse'

# %%
import importlib
import src.fetcher
importlib.reload(src.fetcher)

from src.fetcher import configure_entrez, fetch_sra_studies, fetch_runs_for_bioproject

# make sure entrez is configured
configure_entrez()

# now test
single_id = ids[0]
runs_df = fetch_runs_for_bioproject(single_id)

if runs_df is not None:
    print("Success! Shape:", runs_df.shape)
    print(runs_df[["Run", "BioProject", "LibraryStrategy", "ScientificName"]].head())
else:
    print("fetch returned None - check error message above")
# Out:
# Entrez configured with email: akharya@ucsd.edu
# Error fetching runs for SRA ID 40965287: 'NoneType' object has no attribute 'read_csv'
# fetch returned None - check error message above

# %%
import importlib
import src.fetcher
importlib.reload(src.fetcher)

from src.fetcher import configure_entrez, fetch_sra_studies, fetch_runs_for_bioproject

# make sure entrez is configured
configure_entrez()

# now test
single_id = ids[0]
runs_df = fetch_runs_for_bioproject(single_id)

if runs_df is not None:
    print("Success! Shape:", runs_df.shape)
    print(runs_df[["Run", "BioProject", "LibraryStrategy", "ScientificName"]].head())
else:
    print("fetch returned None - check error message above")
# Out:
# Entrez configured with email: akharya@ucsd.edu
# Error fetching runs for SRA ID 40965287: 'NoneType' object has no attribute 'read_csv'
# fetch returned None - check error message above

# %%
import importlib
import src.fetcher
importlib.reload(src.fetcher)

from src.fetcher import configure_entrez, fetch_sra_studies, fetch_runs_for_bioproject

# make sure entrez is configured
configure_entrez()

# now test
single_id = ids[0]
runs_df = fetch_runs_for_bioproject(single_id)

if runs_df is not None:
    print("Success! Shape:", runs_df.shape)
    print(runs_df[["Run", "BioProject", "LibraryStrategy", "ScientificName"]].head())
else:
    print("fetch returned None - check error message above")
# Out:
# Entrez configured with email: akharya@ucsd.edu
# Error fetching runs for SRA ID 40965287: 'NoneType' object has no attribute 'read_csv'
# fetch returned None - check error message above

# %%
import importlib
import src.fetcher
importlib.reload(src.fetcher)

from src.fetcher import configure_entrez, fetch_sra_studies, fetch_runs_for_bioproject

# make sure entrez is configured
configure_entrez()

# now test
single_id = ids[0]
runs_df = fetch_runs_for_bioproject(single_id)

if runs_df is not None:
    print("Success! Shape:", runs_df.shape)
    print(runs_df[["Run", "BioProject", "LibraryStrategy", "ScientificName"]].head())
else:
    print("fetch returned None - check error message above")
# Out:
# Entrez configured with email: akharya@ucsd.edu
# Success! Shape: (1, 47)
#          Run  BioProject LibraryStrategy  ScientificName
# 0  DRR736714  PRJDB37419        AMPLICON  gut metagenome

# %%
import importlib
import src.fetcher
importlib.reload(src.fetcher)

from src.fetcher import configure_entrez, fetch_sra_studies, fetch_runs_for_bioproject

# make sure entrez is configured
configure_entrez()

# now test
single_id = ids[0]
runs_df = fetch_runs_for_bioproject(single_id)

if runs_df is not None:
    print("Success! Shape:", runs_df.shape)
    print(runs_df[["Run", "BioProject", "LibraryStrategy", "ScientificName"]].head())
else:
    print("fetch returned None - check error message above")
# Out:
# Entrez configured with email: akharya@ucsd.edu
# Error fetching runs for SRA ID 40965287: 'NoneType' object has no attribute 'read_csv'
# fetch returned None - check error message above

# %%
import importlib
import src.fetcher
importlib.reload(src.fetcher)

from src.fetcher import configure_entrez, fetch_sra_studies, fetch_runs_for_bioproject

# make sure entrez is configured
configure_entrez()

# now test
single_id = ids[0]
runs_df = fetch_runs_for_bioproject(single_id)

if runs_df is not None:
    print("Success! Shape:", runs_df.shape)
    print(runs_df[["Run", "BioProject", "LibraryStrategy", "ScientificName"]].head())
else:
    print("fetch returned None - check error message above")
# Out:
# Entrez configured with email: akharya@ucsd.edu
# Error fetching runs for SRA ID 40965287: 'NoneType' object has no attribute 'read_csv'
# fetch returned None - check error message above

# %%
import importlib
import src.fetcher
importlib.reload(src.fetcher)

from src.fetcher import configure_entrez, fetch_sra_studies, fetch_runs_for_bioproject

# make sure entrez is configured
configure_entrez()

# now test
single_id = ids[0]
runs_df = fetch_runs_for_bioproject(single_id)

if runs_df is not None:
    print("Success! Shape:", runs_df.shape)
    print(runs_df[["Run", "BioProject", "LibraryStrategy", "ScientificName"]].head())
else:
    print("fetch returned None - check error message above")
# Out:
# Entrez configured with email: akharya@ucsd.edu
# Success! Shape: (1, 47)
#          Run  BioProject LibraryStrategy  ScientificName
# 0  DRR736714  PRJDB37419        AMPLICON  gut metagenome

# %%
# full pipeline test
from src.filters import check_hard_filters

# get some IDs
ids = fetch_sra_studies("amphibian gut microbiome 16S", max_results=10)

# fetch runs for first ID and check filters
runs_df = fetch_runs_for_bioproject(ids[0])
filters = check_hard_filters(runs_df)

print("BioProject:", runs_df["BioProject"].iloc[0])
print("Host:", runs_df["ScientificName"].iloc[0])
print("Filters:", filters)
# Out:
# Found 577 studies. Fetching 10...
#  Fetched 10 of 10
# BioProject: PRJDB37419
# Host: gut metagenome
# Filters: {'has_16S': True, 'has_WGS': False, 'is_paired': False, 'has_fastq': True, 'passes': False}

# %% [markdown]
# The pipeline works end to end. Data flows from SRA through the fetcher and into the hard filters created previously and returns a structured result.
#
# This specific study fails the tests because it only has 16S data. Since there is no WGS data, it is not paired either and therefore fails two of the four hard filters.
